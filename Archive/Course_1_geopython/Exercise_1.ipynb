# %% [markdown]
# ## Practice Notebook
#
# This notebook was created using **Binder + JupyterLab** and will be saved to **GitHub**.

# %%
# Here you write your name:
name = "Varvara"
# Here you write how confident you are with your python skills:
rating = 9 

print(f"My name is {name} and my Python confidence rating is {rating}/10.")

# %%
pip install nbmerge
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
